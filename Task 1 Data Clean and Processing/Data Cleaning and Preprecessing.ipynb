# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1.Import the dataset and explore basic info (nulls, data types).

# %%
df=pd.read_csv("D:/AI ML Intern Elevate Labs Benglore/Task 1 Data Clean and Processing/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Sanity Check of Data

# %% [markdown]
# a)Checking for missing or null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# TO FIND OUT THE PERCENTAGE OF NULL VALUES PRESENT IN EACH COLUMN

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# b) Checking for duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# c) Checking for garbage values in the object column since mostly garbage values like special character are present in string format that means as object

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("______"*10)
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64
# ____________________________________________________________
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# ____________________________________________________________
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64
# ...

# %% [markdown]
# Inference that we got from sanity check are
# 1) There are missing values present in the columns Age, Cabin, Embarked
# 2) No duplicate rows
# 3) No garbage values

# %% [markdown]
# Exploratory Data Analysis (EDA) : --> Visualize outliers using boxplots

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %% [markdown]
# Outlier Treatment: -> Remove the outliers using boxplot

# %%
def wisker(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
for i in ['Age','Fare']:
    lw,uw=wisker(df[i])
    df[i]=np.where(df[i]<lw,lw,df[i])
    df[i]=np.where(df[i]>uw,uw,df[i])

# %% [markdown]
# =====> Best Practice for Outlier Treatment
#
# Outlier treatment is most appropriate for continuous variables (like Age and Fare), because extreme values can be due to errors, rare events, or data entry mistakes, and can distort analysis and models.
#
# For discrete count variables (like SibSp and Parch), outlier treatment is less common. Their possible values are limited by real-world constraints (e.g., a person can’t have 100 siblings on board), and high values might simply be rare but valid cases
#
# =====> So, Should You Treat All Four Columns?
#
# Definitely treat outliers in Age and Fare.
#
# For SibSp and Parch:
#
# If you see values that are clearly impossible (e.g., someone with 20 siblings on board), you can treat those as outliers.
#
# If the high values are rare but possible, it’s often better to leave them as-is, or just double-check for data entry mistakes.

# %% [markdown]
# Missing Value Treatment: -> 2.Handle missing values using mean/median/imputation.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer()
for i in ['Age']:
    df[i]=imputer.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                   0
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               687
# Embarked              2
# Cabin_imputed         0
# Embarked_imputed      0
# dtype: int64

# %% [markdown]
# Key Points
#
# Why KNNImputer works here:
# By encoding categories into integers and treating them as numerical features, KNN can find similar rows based on all features (including numerical ones like Age/Fare).
#
# Rounding ensures valid categories:
# After imputation, rounding guarantees the encoded values map back to valid original categories.
#
# Handling high cardinality (e.g., Cabin):
# If a column has too many unique values (like Cabin), group them (e.g., by deck: df['Cabin'] = df['Cabin'].str) before encoding.

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer


# Encode 'Cabin' and 'Embarked' into numerical values
categorical_cols = ['Cabin', 'Embarked']
encoders = {}

for col in categorical_cols:
    # Factorize to convert categories to codes (NaN becomes -1)
    codes, uniques = pd.factorize(df[col], use_na_sentinel=True)
    df[f'{col}_encoded'] = codes
    # Replace -1 (NaN) with np.nan for KNNImputer
    df[f'{col}_encoded'] = df[f'{col}_encoded'].replace(-1, np.nan)
    encoders[col] = uniques  # Save for inverse transform

# Select columns for imputation (include encoded categorical)
impute_cols = ['Cabin_encoded', 'Embarked_encoded']

# Initialize KNNImputer
imputer = KNNImputer(n_neighbors=3)
df_imputed = pd.DataFrame(
    imputer.fit_transform(df[impute_cols]),
    columns=impute_cols
)

# Round encoded columns to integers and convert to nullable integer type
df_imputed[['Cabin_encoded', 'Embarked_encoded']] = (
    df_imputed[['Cabin_encoded', 'Embarked_encoded']]
    .round()
    .astype('Int64')  # Use pandas' nullable integer type
)

# Map encoded values back to categories
for col in categorical_cols:
    encoded_col = f'{col}_encoded'
    # Convert to integer and handle NaN safely
    df[f'{col}_imputed'] = df_imputed[encoded_col].apply(
        lambda x: encoders[col][int(x)] if pd.notna(x) else np.nan
    )

# Drop intermediate encoded columns
df = df.drop(columns=['Cabin_encoded', 'Embarked_encoded'])

# Display results
df[['Cabin', 'Cabin_imputed', 'Embarked', 'Embarked_imputed']]
# Out:
#     Cabin Cabin_imputed Embarked Embarked_imputed
# 0     NaN           E46        S                S
# 1     C85           C85        C                C
# 2     NaN           E46        S                S
# 3    C123          C123        S                S
# 4     NaN           E46        S                S
# ..    ...           ...      ...              ...
# 886   NaN           E46        S                S
# 887   B42           B42        S                S
# 888   NaN           E46        S                S
# 889  C148          C148        C                C
# 890   NaN            B4        Q                Q
#
# [891 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                   0
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               687
# Embarked              2
# Cabin_imputed         0
# Embarked_imputed      0
# dtype: int64

# %%
# Replace original 'Cabin' and 'Embarked' with imputed values
df['Cabin'] = df['Cabin_imputed']
df['Embarked'] = df['Embarked_imputed']

# Drop the temporary imputed columns
df.drop(columns=['Cabin_imputed', 'Embarked_imputed'], inplace=True)

# Verify null counts
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# So No missing values after missing treatment

# %% [markdown]
# 4.Normalize/standardize the numerical features.

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Normalize 'Age' column
scaler = MinMaxScaler()
df['age_norm'] = scaler.fit_transform(df[['Age']])

# Normalize 'Fare' column
df['fare_norm'] = scaler.fit_transform(df[['Fare']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  age_norm     891 non-null    float64
#  13  fare_norm    891 non-null    float64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 97.6+ KB

# %%
from sklearn.preprocessing import StandardScaler

# Standardize 'Fare' column
scaler = StandardScaler()
df['fare_std'] = scaler.fit_transform(df[['Fare']])

# Standardize 'Age' column
df['age_std'] = scaler.fit_transform(df[['Age']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  age_norm     891 non-null    float64
#  13  fare_norm    891 non-null    float64
#  14  fare_std     891 non-null    float64
#  15  age_std      891 non-null    float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 111.5+ KB

# %% [markdown]
# 3.Convert categorical features into numerical using encoding.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  age_norm     891 non-null    float64
#  13  fare_norm    891 non-null    float64
#  14  fare_std     891 non-null    float64
#  15  age_std      891 non-null    float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 111.5+ KB

# %% [markdown]
# 1. Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Sex_encoded'] = le.fit_transform(df['Sex'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# 2. One-Hot Encoding

# %%
df = pd.get_dummies(df, columns=['Embarked'], prefix='Embarked')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# I have successfully completed my Data Cleaning and Preprocessing tasks for today!
# I explored the dataset, handled missing values, encoded categorical features, scaled numerical columns, and learned how to spot and treat outliers. These are essential steps for preparing data and building strong machine learning models.
#
# Every clean dataset brings me closer to valuable insights and better results
